# %%
import pandas as pd
import sqlite3
import networkx as nx
from itertools import combinations
from collections import Counter
from build_network import config as cfg

# %%
G = nx.Graph()

# %%
con = sqlite3.connect(cfg.FILE['video_info'])
# sql = '''
# select bvid, uid, labels
# from video_info
# limit 1000
# '''
sql = '''
select bvid, uid, labels
from videos
'''
df = pd.read_sql(sql=sql, con=con, index_col='bvid', )
con.close()

# %%
df['labels'] = df['labels'].apply(lambda x: [kw.strip() for kw in x.split(',')] if x is not None else [])

# %%
df
# Out:
#                    uid                                             labels
# bvid
# BV111421f7WW  67299944           [美国, 韩国, 新年新知识, 海外, 春节, 2024bilibili迎春会]
# BV111421k75P    546189                 [战争, 国际人道法, ICRC, 法律科普局, 法律人专属加油站]
# BV111421q7oW  11280389                                  [历史, 皇帝, 人文历史档案馆]
# BV111421t7db  13897629  [伪纪录片, 模拟恐怖, 史蒂芬市, #24-01, #99空间, #10空间, 新怪谈, ...
# BV111421X7Xx   1959209  [FPS, 180hz, 宿舍神屏, 24寸小金刚, 24寸1080P, PS5, 创维, ...
# ...                ...                                                ...
# BV1ZZ4y1x7qQ   7458285                      [测评, 手机, 爱否速描, 爱否科技, 一加8 Pro]
# BV1Zz4y1Z7PK    546418  [为家乡打call, 4K, 短片, 自制, 旅游, VLOG, 古街, 松阳, HDR, ...
# BV1ZzCZYCEEv   2351309  [2024诺贝尔奖, 镜头, 摄影器材, 摄影技术, 专利, 微距, 移轴, 老蛙, 扯闲篇...
# BV1Zzx9eKETS  10850097                      [原创, 独夫之心, 钥匙扣, 预售, 定制版, 青年军]
# BV1ZZyKYYEQf   1904174                  [学习, 英语, 经验分享, 英语学习, 自然拼读, 零基础英语]
#
# [53012 rows x 2 columns]

# %%
G.size()
# Out:
# 0

# %%
# Add document and author nodes
for bvid, row in df.iterrows():
    G.add_node(bvid, type='document')
    G.add_node(row['uid'], type='author')

    # Add doc-author edge
    G.add_edge(bvid, row['uid'], attribute='author')
    # G.add_edge(row['bvid'], row['uid'], weight=row['duration'], attribute='author')

# %%
# Add keyword nodes and doc-keyword edges
for bvid, row in df.iterrows():
    keywords = row['labels']

    # Add keyword nodes and edges
    for keyword in keywords:
        G.add_node(keyword, type='keyword')

        # Doc-keyword edge
        keyword_count = keywords.count(keyword)
        G.add_edge(bvid, keyword, weight=keyword_count, attribute='contain')

    # Add keyword-keyword edges
    for kw1, kw2 in combinations(keywords, 2):
        if G.has_edge(kw1, kw2):
            G[kw1][kw2]['weight'] += 1
        else:
            G.add_edge(kw1, kw2, weight=1, attribute='co-occurrence')

# %%
import math

# Update weights of edges between keywords
for u, v, data in G.edges(data=True):
    if data.get('attribute') == 'co-occurrence':  # Check if the edge is of type 'mentioned'
        original_weight = data['weight']
        # Avoid math domain error for log(0)
        new_weight = math.log(original_weight+1) 
        G[u][v]['weight'] = new_weight

# %%
# for u, v, data in G.edges(data=True):
#     if data.get('attribute') == 'mentioned':  # Check if the edge attribute is 'mentioned'
#         G[u][v]['attribute'] = 'co-occurrence'

# %%
from collections import defaultdict

# Step 1: Aggregate keyword counts for each author
author_keyword_counts = defaultdict(Counter)

for _, row in df.iterrows():
    author = row['uid']
    keywords = row['labels']
    for keyword in keywords:
        author_keyword_counts[author][keyword] += keywords.count(keyword)

# Step 2: Add edges between authors and keywords
for author, keyword_counts in author_keyword_counts.items():
    for keyword, count in keyword_counts.items():
        if G.has_edge(author, keyword):
            # G[author][keyword]['weight'] += count
            pass
        else:
            G.add_edge(author, keyword, weight=count, attribute='mention')

# log the weight
for u, v, data in G.edges(data=True):
    if data.get('attribute') == 'mention':  
        original_weight = data['weight']
        new_weight = math.log(original_weight+1) 
        G[u][v]['weight'] = new_weight

# %%
# import importlib 
# importlib.reload(cfg)
nx.write_graphml(G, cfg.FILE['graph_label'])

# %%
G = nx.read_graphml(cfg.FILE['graph_label'])

# %%
# Print sample author-keyword edges
random = 0
for u, v, data in G.edges(data=True):
    if data.get('attribute') == 'mention' and G.nodes[u].get('type') == 'author':
        if random % 50 == 0:
            print(f"uid: {u}, keyword: {v:7}, Weight: {round(data['weight'], 3)}")
        random += 1
        if random == 10000:
            break
# Out:
# uid: 67299944, keyword: 美国     , Weight: 6.998
# uid: 67299944, keyword: 潮流     , Weight: 4.263
# uid: 67299944, keyword: 癌症     , Weight: 1.386
# uid: 67299944, keyword: 码农     , Weight: 2.398
# uid: 67299944, keyword: 耐克     , Weight: 1.099
# uid: 67299944, keyword: 灾难     , Weight: 2.996
# uid: 67299944, keyword: 戴口罩    , Weight: 1.099
# uid: 67299944, keyword: 科技与狠活  , Weight: 1.792
# uid: 67299944, keyword: 大阪世博会吉祥物, Weight: 0.693
# uid: 67299944, keyword: ai     , Weight: 1.099
# uid: 67299944, keyword: 韩国人    , Weight: 1.609
# uid: 67299944, keyword: 社会洞察计划 , Weight: 1.946
# uid: 67299944, keyword: 真实故事   , Weight: 2.079
# uid: 67299944, keyword: IPHONE12, Weight: 1.099
# uid: 67299944, keyword: 鼠头鸭脖   , Weight: 0.693
# uid: 67299944, keyword: 哈维尔穿越  , Weight: 0.693
# uid: 67299944, keyword: 老人     , Weight: 1.609
# uid: 67299944, keyword: 小红书    , Weight: 0.693
# uid: 67299944, keyword: 小姐姐    , Weight: 1.386
# uid: 67299944, keyword: 股市     , Weight: 1.099
# uid: 67299944, keyword: 虚拟     , Weight: 0.693
# uid: 67299944, keyword: 618种草大会, Weight: 0.693
# uid: 67299944, keyword: 餐饮业    , Weight: 0.693
# uid: 67299944, keyword: 东方甄选   , Weight: 1.386
# uid: 67299944, keyword: 墓地     , Weight: 0.693
# uid: 67299944, keyword: 新人向    , Weight: 0.693
# uid: 67299944, keyword: 可悲     , Weight: 0.693
# uid: 67299944, keyword: 文明     , Weight: 1.099
# uid: 67299944, keyword: yummy  , Weight: 0.693
# uid: 67299944, keyword: 巴基斯坦   , Weight: 0.693
# uid: 67299944, keyword: #美国名校  , Weight: 0.693
# uid: 67299944, keyword: 抑郁症    , Weight: 1.099
# uid: 67299944, keyword: 食脑虫    , Weight: 0.693
# uid: 67299944, keyword: 宅男的日常生活, Weight: 0.693
# uid: 67299944, keyword: 出去浪vlog, Weight: 0.693
# uid: 67299944, keyword: 情人节    , Weight: 1.099
# uid: 67299944, keyword: 发布会    , Weight: 1.099
# uid: 67299944, keyword: 黑神话悟空  , Weight: 0.693
# uid: 67299944, keyword: 你接种新冠疫苗第几针了?, Weight: 0.693
# uid: 546189, keyword: 新学期行为大赏, Weight: 1.609
# uid: 546189, keyword: 知识研究所  , Weight: 0.693
# uid: 546189, keyword: 五一慢游中国 , Weight: 0.693
# uid: 546189, keyword: 古巴导弹危机 , Weight: 0.693
# uid: 546189, keyword: 校园     , Weight: 1.386
# uid: 546189, keyword: 打开流浪地球2的N种方式, Weight: 0.693
# uid: 546189, keyword: 武汉     , Weight: 0.693
# uid: 546189, keyword: 万国邮政联盟 , Weight: 0.693
# uid: 546189, keyword: 马拉松    , Weight: 0.693
# uid: 546189, keyword: 跨线援助   , Weight: 0.693
# uid: 546189, keyword: 波士顿圆脸  , Weight: 0.693
# uid: 546189, keyword: 撤侨     , Weight: 0.693
# uid: 546189, keyword: AUKUS  , Weight: 0.693
# uid: 546189, keyword: 2023你在B站看了哪些热点, Weight: 0.693
# uid: 546189, keyword: 日军     , Weight: 0.693
# uid: 546189, keyword: 武契奇    , Weight: 0.693
# uid: 11280389, keyword: 魔方周年庆  , Weight: 0.693
# uid: 11280389, keyword: 汉朝     , Weight: 2.833
# uid: 11280389, keyword: 朱棣     , Weight: 1.609
# uid: 11280389, keyword: 宋徽宗    , Weight: 0.693
# uid: 11280389, keyword: 高句丽    , Weight: 0.693
# uid: 11280389, keyword: 一起上岸吧  , Weight: 0.693
# uid: 13897629, keyword: 拍摄     , Weight: 1.609
# uid: 13897629, keyword: 转角遇到春天 , Weight: 2.996
# uid: 13897629, keyword: 万物皆可扭扭棒, Weight: 0.693
# uid: 13897629, keyword: #94空间  , Weight: 1.099
# uid: 13897629, keyword: 日记怪谈   , Weight: 1.792
# uid: 13897629, keyword: 高考前你在做什么？, Weight: 0.693
# uid: 13897629, keyword: 飘渺     , Weight: 0.693
# uid: 13897629, keyword: 愉悦驾驶   , Weight: 0.693
# uid: 13897629, keyword: 闲聊     , Weight: 0.693
# uid: 13897629, keyword: #怪谈    , Weight: 0.693
# uid: 13897629, keyword: 算了你肯定觉得没意思, Weight: 0.693
# uid: 13897629, keyword: 恐怖小说   , Weight: 0.693
# uid: 13897629, keyword: 相机种草   , Weight: 0.693
# uid: 13897629, keyword: 生活万花筒8.0 看见生活B面, Weight: 0.693
# uid: 13897629, keyword: 垃圾核    , Weight: 0.693
# uid: 13897629, keyword: #93-01 , Weight: 0.693
# uid: 13897629, keyword: jumpstyle, Weight: 0.693
# uid: 1959209, keyword: 2024bilibili迎春会, Weight: 1.792
# uid: 1959209, keyword: 键盘     , Weight: 3.989
# uid: 1959209, keyword: 笔记本电脑推荐2024, Weight: 0.693
# uid: 1959209, keyword: 2K     , Weight: 2.079
# uid: 1959209, keyword: 曲面屏    , Weight: 1.386
# uid: 1959209, keyword: 有酷睿Ultra不脱更, Weight: 0.693
# uid: 1959209, keyword: f27g51q pro, Weight: 0.693
# uid: 1959209, keyword: 海信27G7K pro, Weight: 0.693
# uid: 1959209, keyword: 3A大作   , Weight: 1.099
# uid: 1959209, keyword: 配件     , Weight: 0.693
# uid: 1959209, keyword: 优化     , Weight: 0.693
# uid: 1959209, keyword: 2K300Hz, Weight: 1.099
# uid: 1959209, keyword: G52 Plus, Weight: 0.693
# uid: 1959209, keyword: 知识分享官  , Weight: 0.693
# uid: 1959209, keyword: D75    , Weight: 0.693
# uid: 12981887, keyword: 真主党    , Weight: 4.174
# uid: 12981887, keyword: 内战     , Weight: 1.099
# uid: 12981887, keyword: 伊朗革命卫队 , Weight: 1.386
# uid: 12981887, keyword: 以色列宣布进入紧急状态, Weight: 0.693
# uid: 12981887, keyword: 巴赫穆特   , Weight: 1.609
# uid: 12981887, keyword: 特朗普接受检查, Weight: 1.099
# uid: 12981887, keyword: 贝鲁特    , Weight: 1.386
# uid: 12981887, keyword: 朝鲜称其导弹发射针对美国, Weight: 0.693
# uid: 12981887, keyword: 黑山     , Weight: 0.693
# uid: 12981887, keyword: 亚速营    , Weight: 0.693
# uid: 475961, keyword: 电脑     , Weight: 5.342
# uid: 475961, keyword: 触摸屏    , Weight: 0.693
# uid: 475961, keyword: 13700H , Weight: 1.099
# uid: 475961, keyword: BRICK STRIKE, Weight: 0.693
# uid: 475961, keyword: 一体水    , Weight: 1.099
# uid: 475961, keyword: 东方     , Weight: 0.693
# uid: 475961, keyword: 主板     , Weight: 0.693
# uid: 475961, keyword: 线程撕裂者  , Weight: 1.099
# uid: 475961, keyword: 轻薄游戏本  , Weight: 0.693
# uid: 475961, keyword: 路由器    , Weight: 1.386
# uid: 475961, keyword: ARM    , Weight: 0.693
# uid: 475961, keyword: 144Hz  , Weight: 0.693
# uid: 475961, keyword: 联通     , Weight: 0.693
# uid: 475961, keyword: 拯救者2022, Weight: 0.693
# uid: 475961, keyword: 光纤     , Weight: 0.693
# uid: 8969156, keyword: 华为Watch, Weight: 1.386
# uid: 8969156, keyword: MateBook GT 14, Weight: 0.693
# uid: 8969156, keyword: 黑鲨     , Weight: 3.219
# uid: 8969156, keyword: 华为 Mate 60 RS非凡大师, Weight: 0.693
# uid: 8969156, keyword: 骁龙782G , Weight: 0.693
# uid: 8969156, keyword: 天玑     , Weight: 2.773
# uid: 8969156, keyword: 采访     , Weight: 0.693
# uid: 8969156, keyword: 一加5T   , Weight: 1.099
# uid: 8969156, keyword: 奥特曼    , Weight: 0.693
# uid: 8969156, keyword: 8Gen3  , Weight: 1.946
# uid: 8969156, keyword: 手机信息   , Weight: 0.693
# uid: 8969156, keyword: 红魔9S Pro, Weight: 0.693
# uid: 8969156, keyword: 骁龙8    , Weight: 1.946
# uid: 8969156, keyword: 后台保活   , Weight: 0.693
# uid: 8969156, keyword: 诺基亚E72 , Weight: 0.693
# uid: 8969156, keyword: 魅族20   , Weight: 1.386
# uid: 8969156, keyword: Color OS, Weight: 0.693
# uid: 8969156, keyword: 放心去热爱  , Weight: 0.693
# uid: 8969156, keyword: 成王败寇系列 , Weight: 1.386
# uid: 8969156, keyword: 冰川电池   , Weight: 0.693
# uid: 8969156, keyword: #好物分享# , Weight: 0.693
# uid: 8969156, keyword: Redmi K40, Weight: 0.693
# uid: 8969156, keyword: Ace2   , Weight: 1.099
# uid: 8969156, keyword: 华为P60 Pro, Weight: 0.693
# uid: 8969156, keyword: 小姐姐    , Weight: 0.693
# uid: 8969156, keyword: 5G     , Weight: 2.944
# uid: 8969156, keyword: MAVICAIR, Weight: 0.693
# uid: 8969156, keyword: 原创     , Weight: 0.693
# uid: 8969156, keyword: OPPO R11, Weight: 0.693
# uid: 8969156, keyword: Mate60 Pro, Weight: 0.693
# uid: 8969156, keyword: ROG5   , Weight: 0.693
# uid: 8969156, keyword: vivo X90 Pro+, Weight: 0.693
# uid: 8969156, keyword: 小白测评数据库, Weight: 2.197
# uid: 8969156, keyword: 华为nova , Weight: 1.386
# uid: 8969156, keyword: 智能穿戴设备 , Weight: 0.693
# uid: 8969156, keyword: 小米11Pro, Weight: 1.386
# uid: 8969156, keyword: Applewatch, Weight: 0.693
# uid: 8969156, keyword: 马歇尔    , Weight: 0.693
# uid: 8969156, keyword: 百元手机   , Weight: 0.693
# uid: 8969156, keyword: 家庭影院   , Weight: 0.693
# uid: 8969156, keyword: 对比     , Weight: 0.693
# uid: 8969156, keyword: 华为nova11评测, Weight: 0.693
# uid: 8969156, keyword: GPU Turbo, Weight: 0.693
# uid: 8969156, keyword: 手机改造   , Weight: 1.099
# uid: 8969156, keyword: 小米MIX Flip, Weight: 0.693
# uid: 8969156, keyword: 魅族18X  , Weight: 0.693
# uid: 8969156, keyword: 打游戏    , Weight: 0.693
# uid: 8969156, keyword: Redmi K30Pro, Weight: 1.099
# uid: 8969156, keyword: 九牧X90数智马桶, Weight: 0.693
# uid: 8969156, keyword: 初代系统   , Weight: 0.693
# uid: 8969156, keyword: 3D Mark, Weight: 0.693
# uid: 8969156, keyword: 红米5P   , Weight: 0.693
# uid: 8969156, keyword: 滑盖     , Weight: 0.693
# uid: 8969156, keyword: 小屏     , Weight: 0.693
# uid: 8969156, keyword: 华为智慧屏  , Weight: 0.693
# uid: 8372353, keyword: iPhone7Plus, Weight: 1.609
# uid: 8372353, keyword: iPhone , Weight: 3.219
# uid: 8372353, keyword: mini A17Pro, Weight: 0.693
# uid: 8372353, keyword: Exynos2400, Weight: 1.099
# uid: 8372353, keyword: K40PRO , Weight: 0.693
# uid: 8372353, keyword: 奇酷旗舰版  , Weight: 1.099
# uid: 8372353, keyword: 一加5T   , Weight: 1.386
# uid: 8372353, keyword: iPad2022, Weight: 0.693
# uid: 8372353, keyword: 没有雷军   , Weight: 0.693
# uid: 8372353, keyword: 游戏     , Weight: 0.693
# uid: 8372353, keyword: AI手机   , Weight: 1.099
# uid: 8372353, keyword: MIX2   , Weight: 1.099
# uid: 8372353, keyword: 全能轻薄本  , Weight: 0.693
# uid: 8372353, keyword: 麒麟9000S, Weight: 1.386
# uid: 8372353, keyword: 少侠好刀工  , Weight: 0.693
# uid: 8372353, keyword: M4性能   , Weight: 0.693
# uid: 8372353, keyword: 来电新趋势  , Weight: 0.693
# uid: 8372353, keyword: GOOGLE , Weight: 0.693
# uid: 8372353, keyword: Vidda  , Weight: 0.693
# uid: 8372353, keyword: iPhone12, Weight: 2.303
# uid: 8372353, keyword: 原神3.0  , Weight: 0.693
# uid: 8372353, keyword: iQOO Neo9, Weight: 0.693
# uid: 8372353, keyword: 冰龙     , Weight: 0.693
# uid: 8372353, keyword: 一加ACE3V, Weight: 0.693
# uid: 8372353, keyword: AirPods4, Weight: 1.099
# uid: 8372353, keyword: 换电技术   , Weight: 0.693
# uid: 8372353, keyword: MIX Fold3, Weight: 0.693

# %%
def recommend_based_on_keywords(graph, keywords, max_len=None):
    if len(keywords) < 2:
        raise ValueError("At least two keywords are required.")
    
    # Step 1: Find all pairs of keywords
    pairs = [(keywords[i], keywords[j]) for i in range(len(keywords)) for j in range(i+1, len(keywords))]
    recommendation_counts = Counter()

    for kw1, kw2 in pairs:
        try:
            # Step 2: Find the shortest path
            paths = list(nx.all_shortest_paths(graph, source=kw1, target=kw2))
            # paths = nx.all_simple_paths(graph, source=kw1, target=kw2, cutoff=max_len)
            
            for path in paths:
                # Ensure path includes at least one doc or author
                docs_authors = [node for node in path if graph.nodes[node].get('type') in {'document', 'author'}]
                if docs_authors:
                    recommendation_counts.update(docs_authors)

        except nx.NetworkXNoPath:
            continue  # Skip if no path exists between the pair

    # Step 3: Rank authors and docs by their presence in paths
    recommendations = sorted(recommendation_counts.items(), key=lambda x: x[1], reverse=True)

    return recommendations

# %%
recommend_based_on_keywords(G, ['美国', '潮流'])
# Out:
# []

# %%
recommend_based_on_keywords(G_without_kw_edges_vid_nodes, ['美国', '潮流'])
# Out:
# [(67299944, 1), (11336264, 1), (946974, 1), (8736958, 1), (3743849, 1)]

# %%
import copy
G_without_kw_edges = copy.deepcopy(G)
edges_to_remove = [(u, v) for u, v, data in G.edges(data=True) if data.get('attribute') == 'co-occurrence']
# Remove the edges from the graph
G_without_kw_edges.remove_edges_from(edges_to_remove)

# %%
recommend_based_on_keywords(G_without_kw_edges, ['华为', '小米', '手机'])
# Out:
# [('BV1154y1a7e6', 3),
#  ('BV11E411j7jq', 3),
#  ('BV11S411N7xz', 3),
#  ('BV11t411g78A', 3),
#  ('BV1254y1H7Nx', 3),
#  ('BV1254y1p7m9', 3),
#  ('BV12hxzeLEof', 3),
#  ('BV12R4y1M78b', 3),
#  ('BV1354y117fx', 3),
#  ('BV13A411B78e', 3),
#  ('BV13J411v7tg', 3),
#  ('BV13J411y7y1', 3),
#  ('BV13J411z7yD', 3),
#  ('BV13t411w7yv', 3),
#  ('BV13T4y1574a', 3),
#  ('BV1434y1U7fR', 3),
#  ('BV14E41127CS', 3),
#  ('BV14P41157z6', 3),
#  ('BV15A411F7NP', 3),
#  ('BV15a4y1g7VX', 3),
#  ('BV15K4y1k7QH', 3),
#  ('BV15t411c7D5', 3),
#  ('BV15t411R72q', 3),
#  ('BV15w411d7n3', 3),
#  ('BV15Z4y1G7TJ', 3),
#  ('BV1644y1y7kY', 3),
#  ('BV16b411h7Bd', 3),
#  ('BV16b411Y7Ly', 3),
#  ('BV16J411e7CW', 3),
#  ('BV16J411J7tz', 3),
#  ('BV16J411P7px', 3),
#  ('BV16T41117Zn', 3),
#  ('BV16v411w72x', 3),
#  ('BV17SsyeyEXE', 3),
#  ('BV17x4y147qK', 3),
#  ('BV184411U71b', 3),
#  ('BV187411u7D7', 3),
#  ('BV18a411s79j', 3),
#  ('BV18L2gYiEt1', 3),
#  ('BV18w4m167Xd', 3),
#  ('BV194411c7DB', 3),
#  ('BV19i4y197jr', 3),
#  ('BV19t41167L5', 3),
#  ('BV19V411E7CU', 3),
#  ('BV19x411h7Jx', 3),
#  ('BV1A3411k7nM', 3),
#  ('BV1A7411b7nb', 3),
#  ('BV1aaxoeBEka', 3),
#  ('BV1AE411773X', 3),
#  ('BV1AE411L7TW', 3),
#  ('BV1Ag411M75L', 3),
#  ('BV1Ah41187wi', 3),
#  ('BV1aJ411M7XK', 3),
#  ('BV1aJ411Y7MD', 3),
#  ('BV1aL411n799', 3),
#  ('BV1am42137hM', 3),
#  ('BV1aM4y1e7sG', 3),
#  ('BV1At411N7eR', 3),
#  ('BV1at411P7mZ', 3),
#  ('BV1ax411E7yF', 3),
#  ('BV1B142197RM', 3),
#  ('BV1b4411U78Z', 3),
#  ('BV1b4411z7Q2', 3),
#  ('BV1B5411H7hV', 3),
#  ('BV1b5411M7Jm', 3),
#  ('BV1B7411p7Ra', 3),
#  ('BV1bCs8epE26', 3),
#  ('BV1bJ411u7at', 3),
#  ('BV1bK4y197EM', 3),
#  ('BV1Bx411878X', 3),
#  ('BV1c142147bX', 3),
#  ('BV1c7411q73Q', 3),
#  ('BV1c94y1c7c8', 3),
#  ('BV1CE411S7UR', 3),
#  ('BV1CJ41167re', 3),
#  ('BV1CJ411h7Mu', 3),
#  ('BV1Cv411i7vf', 3),
#  ('BV1D441167kM', 3),
#  ('BV1D54y1h7w9', 3),
#  ('BV1Da1ZYKEx5', 3),
#  ('BV1Df4y117ak', 3),
#  ('BV1Dt411w7Fs', 3),
#  ('BV1dV411T7FL', 3),
#  ('BV1dx411t7hq', 3),
#  ('BV1Dz4y1m74j', 3),
#  ('BV1E4411B72M', 3),
#  ('BV1eB4GeSEPx', 3),
#  ('BV1ee4y1e7iW', 3),
#  ('BV1eh411r7MG', 3),
#  ('BV1EM4m127kV', 3),
#  ('BV1eU4y1W7Pq', 3),
#  ('BV1EW411K732', 3),
#  ('BV1F44y1u7vA', 3),
#  ('BV1fA411v7LR', 3),
#  ('BV1fb4y1f7au', 3),
#  ('BV1fE411H7Pk', 3),
#  ('BV1fE411k7uo', 3),
#  ('BV1Ff4y1z7pY', 3),
#  ('BV1fJ4115724', 3),
#  ('BV1fJ411b7ua', 3),
#  ('BV1FL4y1A7Ak', 3),
#  ('BV1FTmVYYExd', 3),
#  ('BV1FV411d713', 3),
#  ('BV1FW411L7VQ', 3),
#  ('BV1G7411s7UN', 3),
#  ('BV1g7411T7Yv', 3),
#  ('BV1Gb411J7Vd', 3),
#  ('BV1gJ411K78w', 3),
#  ('BV1GJ411p7xd', 3),
#  ('BV1gK411N7kU', 3),
#  ('BV1gv411M7qE', 3),
#  ('BV1gz421v7S1', 3),
#  ('BV1H7411m72V', 3),
#  ('BV1hE411M7ix', 3),
#  ('BV1hJ411R7kA', 3),
#  ('BV1hN411o7s5', 3),
#  ('BV1HS4y1D7xS', 3),
#  ('BV1HU4KeUERY', 3),
#  ('BV1hu4y1j71b', 3),
#  ('BV1hW411R74R', 3),
#  ('BV1HZ421N7TM', 3),
#  ('BV1i3411c7RB', 3),
#  ('BV1i4411k7uk', 3),
#  ('BV1i54y157uB', 3),
#  ('BV1iA411M7rG', 3),
#  ('BV1iN4y1K7T6', 3),
#  ('BV1iW41157bx', 3),
#  ('BV1iY411F7Uw', 3),
#  ('BV1j4411s7fN', 3),
#  ('BV1jb2PYYE1h', 3),
#  ('BV1jBxQeFEHj', 3),
#  ('BV1ji4y1V7Rn', 3),
#  ('BV1jJ41187uY', 3),
#  ('BV1jJ411A7gv', 3),
#  ('BV1jJ411g73U', 3),
#  ('BV1jJ411T7tV', 3),
#  ('BV1jK411T72f', 3),
#  ('BV1jk4y1H7KQ', 3),
#  ('BV1jV41147a2', 3),
#  ('BV1jWxwexELC', 3),
#  ('BV1k4411K7sE', 3),
#  ('BV1K5411g7s7', 3),
#  ('BV1k54y1C7R6', 3),
#  ('BV1k64y1o7YB', 3),
#  ('BV1k7411q7Zt', 3),
#  ('BV1Kb411r7W7', 3),
#  ('BV1Kb411z7ae', 3),
#  ('BV1kJ411h7g4', 3),
#  ('BV1ko4y1W7ke', 3),
#  ('BV1kp4y197L7', 3),
#  ('BV1ks411g7XT', 3),
#  ('BV1Kx411B7yC', 3),
#  ('BV1L7421R7EB', 3),
#  ('BV1LA41177LU', 3),
#  ('BV1LJ411i7fR', 3),
#  ('BV1LL41177MK', 3),
#  ('BV1Ls4y1R7kg', 3),
#  ('BV1M441197Yf', 3),
#  ('BV1m4411k7rB', 3),
#  ('BV1M4411r7Ve', 3),
#  ('BV1M9xJefE7V', 3),
#  ('BV1mE4ze7EVc', 3),
#  ('BV1mJ411W786', 3),
#  ('BV1MM411D7QX', 3),
#  ('BV1MW411V7bS', 3),
#  ('BV1Mz421v7Cd', 3),
#  ('BV1N4411p7UH', 3),
#  ('BV1N4421U7a9', 3),
#  ('BV1NJ411S7zi', 3),
#  ('BV1NJ411t78Q', 3),
#  ('BV1nM4m1k7Jh', 3),
#  ('BV1nt411371X', 3),
#  ('BV1nV2RY1EF8', 3),
#  ('BV1o4411Q7d9', 3),
#  ('BV1oB4y1b7Wk', 3),
#  ('BV1oBCdYiE4y', 3),
#  ('BV1oG4VexEbK', 3),
#  ('BV1oK4y1u7Q2', 3),
#  ('BV1oL411H7uW', 3),
#  ('BV1omxqedE3M', 3),
#  ('BV1P64y1X76i', 3),
#  ('BV1p7411575d', 3),
#  ('BV1pa4y1v7KA', 3),
#  ('BV1PD4y1D766', 3),
#  ('BV1pi4y117j1', 3),
#  ('BV1Pk4y1z76i', 3),
#  ('BV1PM4m1Y76Y', 3),
#  ('BV1pt411578F', 3),
#  ('BV1Pt4y1U79X', 3),
#  ('BV1px411f7rE', 3),
#  ('BV1px411n7Jg', 3),
#  ('BV1Q34y1x7Mt', 3),
#  ('BV1Q441127WZ', 3),
#  ('BV1Q441197Eh', 3),
#  ('BV1Q4411V75s', 3),
#  ('BV1qe411p7PE', 3),
#  ('BV1QJ411S7Yy', 3),
#  ('BV1QS421Q7FR', 3),
#  ('BV1Qt411u71m', 3),
#  ('BV1qU4y1V7Ab', 3),
#  ('BV1qv4y1o7Xo', 3),
#  ('BV1qx411W7XV', 3),
#  ('BV1qy411H7zi', 3),
#  ('BV1R4411p7ry', 3),
#  ('BV1rb411e7UR', 3),
#  ('BV1RM14YHEgC', 3),
#  ('BV1Rm4y1N7RU', 3),
#  ('BV1rN41137Tg', 3),
#  ('BV1RW421Q7Gx', 3),
#  ('BV1s34y1D7d6', 3),
#  ('BV1s4411B7ZK', 3),
#  ('BV1sb4y1d77v', 3),
#  ('BV1Sd1fYzEH5', 3),
#  ('BV1Sd4y1k716', 3),
#  ('BV1SE41187Uo', 3),
#  ('BV1SE411v74v', 3),
#  ('BV1SJ411n7i4', 3),
#  ('BV1SK4y1e7gz', 3),
#  ('BV1ST4y1f71J', 3),
#  ('BV1Sy411H7C3', 3),
#  ('BV1T4421S77o', 3),
#  ('BV1T54y1y7wL', 3),
#  ('BV1T7411U7nU', 3),
#  ('BV1TB4y1B7Wt', 3),
#  ('BV1tE411k7i6', 3),
#  ('BV1tg411K7vB', 3),
#  ('BV1tJ41187g2', 3),
#  ('BV1TJ411x7rm', 3),
#  ('BV1tN411p7K4', 3),
#  ('BV1Tt411c7FF', 3),
#  ('BV1Tv411v72R', 3),
#  ('BV1uE41177VK', 3),
#  ('BV1Uf421v7dv', 3),
#  ('BV1UJ411g7Gf', 3),
#  ('BV1uL411N75d', 3),
#  ('BV1ut4y1B7Bk', 3),
#  ('BV1uW411u7sK', 3),
#  ('BV1UX4y1N78C', 3),
#  ('BV1V441127Sj', 3),
#  ('BV1V4411c7A3', 3),
#  ('BV1v4CfYrENU', 3),
#  ('BV1vb411y7Bb', 3),
#  ('BV1vM4y1N7QS', 3),
#  ('BV1VM4y1w7b3', 3),
#  ('BV1VT4y1g7Zt', 3),
#  ('BV1Vy4y1t7xK', 3),
#  ('BV1Vy4y1U725', 3),
#  ('BV1w4411C7rC', 3),
#  ('BV1w4411f7Yf', 3),
#  ('BV1w4411y7Vq', 3),
#  ('BV1wi4y137Ny', 3),
#  ('BV1wJ411X71M', 3),
#  ('BV1WP4y157bd', 3),
#  ('BV1WV41127Bk', 3),
#  ('BV1wW411L7Yn', 3),
#  ('BV1wW411S7w5', 3),
#  ('BV1Ww4m1k7yN', 3),
#  ('BV1X4411m7bA', 3),
#  ('BV1xa4y1i7DT', 3),
#  ('BV1Xb411H7pG', 3),
#  ('BV1Xc411o79p', 3),
#  ('BV1XJ411L7YW', 3),
#  ('BV1xM4m117xq', 3),
#  ('BV1XNxge6EHm', 3),
#  ('BV1XQ4y1C7XP', 3),
#  ('BV1Xq4y1j7Qf', 3),
#  ('BV1xt41157Ts', 3),
#  ('BV1xW41167aD', 3),
#  ('BV1y7411G75t', 3),
#  ('BV1yb411g7Kx', 3),
#  ('BV1yi421r7ne', 3),
#  ('BV1yJ411n7nA', 3),
#  ('BV1yJ411r72h', 3),
#  ('BV1Yo4y127s1', 3),
#  ('BV1Yp4y1z7oq', 3),
#  ('BV1Ys411A7Hf', 3),
#  ('BV1Yt411A7Au', 3),
#  ('BV1yt4y127vP', 3),
#  ('BV1yW411T7Eu', 3),
#  ('BV1YW411Z7Mm', 3),
#  ('BV1yy4y127E5', 3),
#  ('BV1z14y187eX', 3),
#  ('BV1Z1xxetE7c', 3),
#  ('BV1z4411r7TE', 3),
#  ('BV1Z7tvexEmN', 3),
#  ('BV1zb411t7Xk', 3),
#  ('BV1Zi4y1o7mq', 3),
#  ('BV1ZJ411V78U', 3),
#  ('BV1Zp4y1U7X2', 3),
#  ('BV1ZS421X7jp', 3),
#  ('BV1zS4y1R7AY', 3),
#  ('BV1Zt4y1e7iK', 3),
#  ('BV1zV411h76y', 3),
#  ('BV1zW411V7df', 3),
#  ('BV1zz421i7Mt', 3),
#  (67299944, 3),
#  (1959209, 3),
#  (475961, 3),
#  (8969156, 3),
#  (8372353, 3),
#  (8482768, 3),
#  (67991584, 3),
#  (3766866, 3),
#  (546418, 3),
#  (367877, 3),
#  (2233213, 3),
#  (10850097, 3),
#  (61086273, 3),
#  (50444181, 3),
#  (11336264, 3),
#  (8784855, 3),
#  (12590, 3),
#  (946974, 3),
#  (41820, 3),
#  (4401694, 3),
#  (13565996, 3),
#  (13407784, 3),
#  (9321359, 3),
#  (67368617, 3),
#  (12145493, 3),
#  (287795639, 3),
#  (957060, 3),
#  (5626102, 3),
#  (65764710, 3),
#  (12300996, 3),
#  (18937162, 3),
#  (3530725, 3),
#  (7458285, 3),
#  (11978336, 3),
#  (3743849, 3),
#  (10698051, 3),
#  ('BV114411e7sR', 1),
#  ('BV11b411q7QB', 1),
#  ('BV11b411u78G', 1),
#  ('BV11E411s7Jj', 1),
#  ('BV11k4y1j7xD', 1),
#  ('BV11R4y137Y5', 1),
#  ('BV11U411m7Hv', 1),
#  ('BV11W4y1c7hU', 1),
#  ('BV11wS8YoECx', 1),
#  ('BV124411r7SF', 1),
#  ('BV12E411M7zA', 1),
#  ('BV12K4y1P71A', 1),
#  ('BV12t411a72q', 1),
#  ('BV12W411R7Cf', 1),
#  ('BV137411U7KH', 1),
#  ('BV13J41167pZ', 1),
#  ('BV14q4y1m7Rc', 1),
#  ('BV15L411D7U1', 1),
#  ('BV15o4y197pa', 1),
#  ('BV15t411W79t', 1),
#  ('BV15z4y1u7dR', 1),
#  ('BV16b411i7kf', 1),
#  ('BV16g4y1N7Mf', 1),
#  ('BV16H4y1J7Jo', 1),
#  ('BV16m4y1N78Y', 1),
#  ('BV16p411R7r2', 1),
#  ('BV16u4y1y7U3', 1),
#  ('BV16W411w7UV', 1),
#  ('BV174411f7LJ', 1),
#  ('BV174411v7UN', 1),
#  ('BV1744y1H7X1', 1),
#  ('BV17C4y1N7Ev', 1),
#  ('BV17D4y1r7Su', 1),
#  ('BV17r421T7vT', 1),
#  ('BV17s41177dQ', 1),
#  ('BV17v411i7jk', 1),
#  ('BV18N411Q717', 1),
#  ('BV18v411L7gG', 1),
#  ('BV19K411L7vs', 1),
#  ('BV19q4y1B7kZ', 1),
#  ('BV19r421w7QC', 1),
#  ('BV19RSgYSEg1', 1),
#  ('BV19t411x7cG', 1),
#  ('BV19W4y1f7ci', 1),
#  ('BV1A9tUeuEFy', 1),
#  ('BV1aa23YCESF', 1),
#  ('BV1ab28YbEbX', 1),
#  ('BV1Ab411C7KC', 1),
#  ('BV1ae411S7Jg', 1),
#  ('BV1Ag4y1F728', 1),
#  ('BV1ax411i7hD', 1),
#  ('BV1b1saefEjJ', 1),
#  ('BV1B4411w7Jx', 1),
#  ('BV1B8pgekE2m', 1),
#  ('BV1bb41187JL', 1),
#  ('BV1BDxDewEKP', 1),
#  ('BV1BMSWYbEH8', 1),
#  ('BV1bT4y1o7sG', 1),
#  ('BV1C3CfYQE4t', 1),
#  ('BV1CBDEY4EKE', 1),
#  ('BV1cE411C7k7', 1),
#  ('BV1CJ411a77m', 1),
#  ('BV1CV411e7cf', 1),
#  ('BV1cv411q7oi', 1),
#  ('BV1Cv4y1G7vS', 1),
#  ('BV1cw411B7bc', 1),
#  ('BV1cx411q7co', 1),
#  ('BV1cy4y1C7LD', 1),
#  ('BV1d4411v76y', 1),
#  ('BV1D741187js', 1),
#  ('BV1Dc411s7af', 1),
#  ('BV1DE411t7tw', 1),
#  ('BV1Dh41137xZ', 1),
#  ('BV1Dm421V74L', 1),
#  ('BV1dN4y1m7kX', 1),
#  ('BV1dP4y1c7rq', 1),
#  ('BV1DP4y1W7um', 1),
#  ('BV1Dq4y1W7AC', 1),
#  ('BV1Dx4119729', 1),
#  ('BV1e2S6YqEbw', 1),
#  ('BV1e7411771R', 1),
#  ('BV1e84y1j7CD', 1),
#  ('BV1ec411k7fA', 1),
#  ('BV1eN4DedEEp', 1),
#  ('BV1eo4y1F7vo', 1),
#  ('BV1Ep411d7fy', 1),
#  ('BV1eP4y1H7Q3', 1),
#  ('BV1er421M75e', 1),
#  ('BV1es421K7dK', 1),
#  ('BV1Fb411p7HQ', 1),
#  ('BV1Fb4y1D7HE', 1),
#  ('BV1fL2CYyECd', 1),
#  ('BV1Ft41187ME', 1),
#  ('BV1Ft411Q7Fw', 1),
#  ('BV1Ft411Q7Kx', 1),
#  ('BV1ft411t7LT', 1),
#  ('BV1Fx411o7ML', 1),
#  ('BV1Fx4y1Y77H', 1),
#  ('BV1gD4y1E7gA', 1),
#  ('BV1giykYsEqV', 1),
#  ('BV1gL411L7Ky', 1),
#  ('BV1gTpceqESn', 1),
#  ('BV1gw4m11723', 1),
#  ('BV1h24y1j7q8', 1),
#  ('BV1h54y1k7M6', 1),
#  ('BV1H7411E7Sr', 1),
#  ('BV1hb411A7Uw', 1),
#  ('BV1hGyXYDEEM', 1),
#  ('BV1hm42137vY', 1),
#  ('BV1Hs421G7TC', 1),
#  ('BV1Ht41137kM', 1),
#  ('BV1Hy4y147Rt', 1),
#  ('BV1HZxsehE6T', 1),
#  ('BV1i41TYqEqX', 1),
#  ('BV1J441117hA', 1),
#  ('BV1j6mjYqEqg', 1),
#  ('BV1jb411k78A', 1),
#  ('BV1Jg41117yU', 1),
#  ('BV1JJ4m1t7gU', 1),
#  ('BV1JJ4m1T7mp', 1),
#  ('BV1jr421K78y', 1),
#  ('BV1jr421L75o', 1),
#  ('BV1k1xXeVEmU', 1),
#  ('BV1kE4m1R77g', 1),
#  ('BV1KH4y157TB', 1),
#  ('BV1Kp411o7xN', 1),
#  ('BV1Ks4y1q7aA', 1),
#  ('BV1kt41147Q2', 1),
#  ('BV1kv411e7Nh', 1),
#  ('BV1kW41117fe', 1),
#  ('BV1kx41127uH', 1),
#  ('BV1L4411K7S5', 1),
#  ('BV1Lb411m7cM', 1),
#  ('BV1LF411Y71Q', 1),
#  ('BV1LU411S76L', 1),
#  ('BV1Lx411g7mb', 1),
#  ('BV1LY411s7my', 1),
#  ('BV1m7411379V', 1),
#  ('BV1m94y1W7KF', 1),
#  ('BV1Mb411s7xq', 1),
#  ('BV1Mb4y1o7zJ', 1),
#  ('BV1MN411r7cw', 1),
#  ('BV1mS4y157C2', 1),
#  ('BV1MS4y1M7qD', 1),
#  ('BV1mvmPYHEDS', 1),
#  ('BV1mw4m1r7Vs', 1),
#  ('BV1MW4y1N7qg', 1),
#  ('BV1Mx4y1s7TA', 1),
#  ('BV1N4411B7Q2', 1),
#  ('BV1n4421o7nY', 1),
#  ('BV1n7411F7kR', 1),
#  ('BV1Na411y7DD', 1),
#  ('BV1Nb411V7mL', 1),
#  ('BV1ncxxebE8C', 1),
#  ('BV1NF411U7Sd', 1),
#  ('BV1NJ41117ns', 1),
#  ('BV1Nk4y1m7AU', 1),
#  ('BV1Nm42137qp', 1),
#  ('BV1Nt421n7gz', 1),
#  ('BV1NV411j7u9', 1),
#  ('BV1NW41167XS', 1),
#  ('BV1NW411q7PK', 1),
#  ('BV1nY1fYsEfu', 1),
#  ('BV1o14y1z7Am', 1),
#  ('BV1op4y1C7jy', 1),
#  ('BV1ot4y1k7tv', 1),
#  ('BV1oU4y1E7MU', 1),
#  ('BV1oXtkeyExG', 1),
#  ('BV1P8411Q7aE', 1),
#  ('BV1pb411B7ah', 1),
#  ('BV1pb411w75k', 1),
#  ('BV1pK421y7Hx', 1),
#  ('BV1PL4y1Y7fP', 1),
#  ('BV1pr4y1Z7T7', 1),
#  ('BV1PUp4evEvq', 1),
#  ('BV1pV4y1k7Qw', 1),
#  ('BV1px411G74e', 1),
#  ('BV1q3411i7ow', 1),
#  ('BV1Q8411E7aq', 1),
#  ('BV1Qb411W7cm', 1),
#  ('BV1QB4y197v7', 1),
#  ('BV1Qg41177ar', 1),
#  ('BV1qg4y1v7zT', 1),
#  ('BV1QH4y1F7fb', 1),
#  ('BV1qNSdYDEyK', 1),
#  ('BV1qT411m7aD', 1),
#  ('BV1QW411h78F', 1),
#  ('BV1r44y1a7YQ', 1),
#  ('BV1rE411f7NF', 1),
#  ('BV1Rf421i7yz', 1),
#  ('BV1Rg411N7Bu', 1),
#  ('BV1RM411Y7MM', 1),
#  ('BV1Rt411M7gQ', 1),
#  ('BV1Rw411B7Gz', 1),
#  ('BV1S4411W7CG', 1),
#  ('BV1S5411M7k3', 1),
#  ('BV1sb4y1H7ym', 1),
#  ('BV1SJ411N7Zf', 1),
#  ('BV1sM4y1e7Tw', 1),
#  ('BV1so42evEtE', 1),
#  ('BV1sq4y1z7Qm', 1),
#  ('BV1T4yeYbESD', 1),
#  ('BV1tE411v7Df', 1),
#  ('BV1Ti4y1W726', 1),
#  ('BV1TM411h7bA', 1),
#  ('BV1ts411B78k', 1),
#  ('BV1tS421978Z', 1),
#  ('BV1tt411r7Tm', 1),
#  ('BV1TW411h7Pg', 1),
#  ('BV1U741177AV', 1),
#  ('BV1uE411b789', 1),
#  ('BV1uE4m1d7Nv', 1),
#  ('BV1uH4y1F7sC', 1),
#  ('BV1ui421r712', 1),
#  ('BV1us411p7sP', 1),
#  ('BV1uW411N7ba', 1),
#  ('BV1UY44eJECK', 1),
#  ('BV1UY4y1Y7UD', 1),
#  ('BV1v4411r7xb', 1),
#  ('BV1VADvYxEZB', 1),
#  ('BV1vE411X7vz', 1),
#  ('BV1Vm4y1c7Pm', 1),
#  ('BV1VmmNYAEMW', 1),
#  ('BV1vt411p7Xn', 1),
#  ('BV1vV41167h4', 1),
#  ('BV1VV4y127ev', 1),
#  ('BV1VW411Z7kz', 1),
#  ('BV1vx411H7sj', 1),
#  ('BV1W14y1k7fh', 1),
#  ('BV1W341127HH', 1),
#  ('BV1Wi4y1t7XR', 1),
#  ('BV1wN411m7yV', 1),
#  ('BV1wt411W7MN', 1),
#  ('BV1wW411h7Tk', 1),
#  ('BV1wx411Z7VH', 1),
#  ('BV1wY4y1K7ae', 1),
#  ('BV1WZ421g7Eg', 1),
#  ('BV1wZ4y1h7kd', 1),
#  ('BV1Xb411g7oV', 1),
#  ('BV1xh41167QZ', 1),
#  ('BV1Xo4y177vj', 1),
#  ('BV1xoseeFEAy', 1),
#  ('BV1xs411q7HN', 1),
#  ('BV1Xs4y1u7du', 1),
#  ('BV1Xt41137Vv', 1),
#  ('BV1XT421k7uj', 1),
#  ('BV1Xw411K7B9', 1),
#  ('BV1xW411V7Hc', 1),
#  ('BV1Xx411R7sK', 1),
#  ('BV1XY4y1v7F5', 1),
#  ('BV1Yex4eREDy', 1),
#  ('BV1yg4y1i7jd', 1),
#  ('BV1Yh411a78i', 1),
#  ('BV1YJ411u7Ud', 1),
#  ('BV1Ys411w74G', 1),
#  ('BV1Yt411C75L', 1),
#  ('BV1Yt411n7Bh', 1),
#  ('BV1Z94y1b7wr', 1),
#  ('BV1Zb411F7r9', 1),
#  ('BV1ZKSyYnENC', 1),
#  ('BV1zr4y1R7Cj', 1),
#  ('BV1Zs411g7kd', 1),
#  ('BV1zt411v7rL', 1),
#  ('BV1Zt421J782', 1),
#  ('BV1zv421i7v8', 1),
#  ('BV1zW411F7WL', 1),
#  ('BV1zw4m1k7q7', 1),
#  (37029661, 1),
#  (12119849, 1),
#  ('BV11341127wL', 1),
#  ('BV114411u7hG', 1),
#  ('BV1154y137d1', 1),
#  ('BV11g411S7c7', 1),
#  ('BV11kxuexEPV', 1),
#  ('BV11p411Z7oC', 1),
#  ('BV11T41177rw', 1),
#  ('BV12a411T7Se', 1),
#  ('BV12i4y1K7qA', 1),
#  ('BV12J411i72D', 1),
#  ('BV12K4y1t7KG', 1),
#  ('BV12L4y1u7rH', 1),
#  ('BV12u4y187qk', 1),
#  ('BV12V2LYGE2J', 1),
#  ('BV12W411G79a', 1),
#  ('BV12Z4y1u7ic', 1),
#  ('BV13642137nG', 1),
#  ('BV13b4y1r7iN', 1),
#  ('BV13e4y1x7J8', 1),
#  ('BV13j41147V9', 1),
#  ('BV13L411c7XY', 1),
#  ('BV13m4y137Me', 1),
#  ('BV13M4y1r7Bu', 1),
#  ('BV13V411Z77i', 1),
#  ('BV13X4y157Y2', 1),
#  ('BV13Z1LYJEEP', 1),
#  ('BV143411873x', 1),
#  ('BV14k4y1C7ay', 1),
#  ('BV14M4y1s7FU', 1),
#  ('BV14W411j7AQ', 1),
#  ('BV14x411Q7Fu', 1),
#  ('BV14X4HewEgm', 1),
#  ('BV154411U7Ab', 1),
#  ('BV154411v7D6', 1),
#  ('BV15b4y1n7YY', 1),
#  ('BV15D4y1S7kh', 1),
#  ('BV15J411v7vM', 1),
#  ('BV15m4y1979E', 1),
#  ('BV15P411f7fN', 1),
#  ('BV16441157Nz', 1),
#  ('BV164411f7k2', 1),
#  ('BV165411D7qT', 1),
#  ('BV16a411A7sx', 1),
#  ('BV16c4peREEc', 1),
#  ('BV16h411j7W6', 1),
#  ('BV16J41197dc', 1),
#  ('BV16R4y1W7cz', 1),
#  ('BV16U4y127ZK', 1),
#  ('BV16v4y1o7uc', 1),
#  ('BV16z411b7AK', 1),
#  ('BV1754y1D7r8', 1),
#  ('BV17B4y1T7oQ', 1),
#  ('BV17C41137AA', 1),
#  ('BV17E4m1d7CJ', 1),
#  ('BV17s411J7WX', 1),
#  ('BV17t421g7iB', 1),
#  ('BV1854y1C76b', 1),
#  ('BV188411s7Kq', 1),
#  ('BV18J411R7UQ', 1),
#  ('BV18s411u7hC', 1),
#  ('BV18s411w7zD', 1),
#  ('BV18U411S7g7', 1),
#  ('BV1914y167Eq', 1),
#  ('BV194411H7AB', 1),
#  ('BV19D421J7fB', 1),
#  ('BV19E411Z7Dr', 1),
#  ('BV19J411z7UL', 1),
#  ('BV19L411E763', 1),
#  ('BV19p411o7eV', 1),
#  ('BV19Q4y1N7v9', 1),
#  ('BV19S48eNEdF', 1),
#  ('BV19U4y1F7Pq', 1),
#  ('BV19w411R7gQ', 1),
#  ('BV1A24y1K7ey', 1),
#  ('BV1AA411b7G7', 1),
#  ('BV1Ag4y1a7dN', 1),
#  ('BV1ah411f7L2', 1),
#  ('BV1ah4y1N77P', 1),
#  ('BV1aJ411K71y', 1),
#  ('BV1aq4y1C7rj', 1),
#  ('BV1aS4y1F7Kb', 1),
#  ('BV1at411N7kX', 1),
#  ('BV1AT4y137cp', 1),
#  ('BV1aV411p7ff', 1),
#  ('BV1Av411r7UB', 1),
#  ('BV1AW411A7Do', 1),
#  ('BV1AW411T786', 1),
#  ('BV1AZ4y1W7k1', 1),
#  ('BV1b34y167yf', 1),
#  ('BV1b34y1n7e2', 1),
#  ('BV1b441167fc', 1),
#  ('BV1B44y167xE', 1),
#  ('BV1B7411e7mU', 1),
#  ('BV1BA41137JL', 1),
#  ('BV1Ba4y1P7Th', 1),
#  ('BV1Bb411H7fK', 1),
#  ('BV1Bd4y117TY', 1),
#  ('BV1Bf4y1j7x9', 1),
#  ('BV1bH4aeAEdJ', 1),
#  ('BV1bK4y1z7kJ', 1),
#  ('BV1bM411U7uq', 1),
#  ('BV1bm4y1k7AN', 1),
#  ('BV1bt4y1A7g3', 1),
#  ('BV1c7411R7WD', 1),
#  ('BV1CE411C757', 1),
#  ('BV1cg4y1m73J', 1),
#  ('BV1CK411A7Rr', 1),
#  ('BV1cM4y1K76X', 1),
#  ('BV1CP411V7pg', 1),
#  ('BV1cr4y1i7YL', 1),
#  ('BV1CT4y1E7hi', 1),
#  ('BV1CT4y1g78n', 1),
#  ('BV1CW411R7dU', 1),
#  ('BV1CY411H7j2', 1),
#  ('BV1Cy4y1z7uM', 1),
#  ('BV1D64y1F7Gq', 1),
#  ('BV1Db4y1U7Kk', 1),
#  ('BV1DC4y1p7nD', 1),
#  ('BV1dD4y1c77e', 1),
#  ('BV1de41117Wd', 1),
#  ('BV1DE411V7Dt', 1),
#  ('BV1dF411D7Uu', 1),
#  ('BV1DH4y1D74j', 1),
#  ('BV1dJ411z7HB', 1),
#  ('BV1DK411u7YY', 1),
#  ('BV1dL411c7rK', 1),
#  ('BV1dLbAehE4A', 1),
#  ('BV1dN411Q7Gt', 1),
#  ('BV1DP4y1t7Sj', 1),
#  ('BV1dr421W7Yj', 1),
#  ('BV1Ds411u7qJ', 1),
#  ('BV1Dt411r7gN', 1),
#  ('BV1dW411K7mY', 1),
#  ('BV1dX4y1G7wn', 1),
#  ('BV1dX4y1t7qF', 1),
#  ('BV1Dz421y7Et', 1),
#  ('BV1E4411S7cW', 1),
#  ('BV1E4411X7UA', 1),
#  ('BV1ee411u7ww', 1),
#  ('BV1EF411B7Xm', 1),
#  ('BV1EG411i7sq', 1),
#  ('BV1Ei4y1w7W4', 1),
#  ('BV1EK4y1b7hK', 1),
#  ('BV1EL4y1P7pm', 1),
#  ('BV1Em4y1r7YE', 1),
#  ('BV1EN41127oP', 1),
#  ('BV1eo4y1s7S2', 1),
#  ('BV1et41177xr', 1),
#  ('BV1eT4y1y7rs', 1),
#  ('BV1eUxYezEtb', 1),
#  ('BV1ew411f7Vk', 1),
#  ('BV1EW411V7Fy', 1),
#  ('BV1Ex41117Xb', 1),
#  ('BV1Ex411M7aP', 1),
#  ('BV1Ex411Q7Eq', 1),
#  ('BV1F14y1E7oN', 1),
#  ('BV1F7411M71C', 1),
#  ('BV1fA411g7Zj', 1),
#  ('BV1Fb411M7LT', 1),
#  ('BV1fb411p7Zf', 1),
#  ('BV1fE411o7Yk', 1),
#  ('BV1fi4y1b7VR', 1),
#  ('BV1FJ411i7Wr', 1),
#  ('BV1ft41167DF', 1),
#  ('BV1fx41177Pz', 1),
#  ('BV1fx411A7DS', 1),
#  ('BV1Ga41167XT', 1),
#  ('BV1GJ411e7RP', 1),
#  ('BV1GL41137Lb', 1),
#  ('BV1gM4y1z71i', 1),
#  ('BV1gp411Z7bX', 1),
#  ('BV1Gp4y1q7LT', 1),
#  ('BV1gs4y197kG', 1),
#  ('BV1gs4y1E7KS', 1),
#  ('BV1gt411r7B7', 1),
#  ('BV1gU4y1a7rj', 1),
#  ('BV1Gx411E7Xc', 1),
#  ('BV1Gz41187f6', 1),
#  ('BV1gZ4y1i7Fv', 1),
#  ('BV1H4411q7Vx', 1),
#  ('BV1h44y147NF', 1),
#  ('BV1hb41187r1', 1),
#  ('BV1hB4y1m7sP', 1),
#  ('BV1Hf4y1777P', 1),
#  ('BV1hJ411y7Fd', 1),
#  ('BV1Hk4y1J75h', 1),
#  ('BV1hP4y1K7hz', 1),
#  ('BV1Hs411E7kA', 1),
#  ('BV1hW411A7fA', 1),
#  ('BV1HW411j7MR', 1),
#  ('BV1Hx411k7Bv', 1),
#  ('BV1Hz4y1D7UA', 1),
#  ('BV1i54y1x7Qm', 1),
#  ('BV1ip4y1T7kU', 1),
#  ('BV1iT4y1E7ir', 1),
#  ('BV1iW411C7R8', 1),
#  ('BV1iW411G7Yt', 1),
#  ('BV1iW411v7Mo', 1),
#  ('BV1ix411M7Ax', 1),
#  ('BV1iy411H7vG', 1),
#  ('BV1ja411c7Dq', 1),
#  ('BV1JB4y137Pp', 1),
#  ('BV1Jh411r7Ls', 1),
#  ('BV1ji421r7wL', 1),
#  ('BV1jj41127kL', 1),
#  ('BV1jK411b7Gy', 1),
#  ('BV1jm4y1Q7QW', 1),
#  ('BV1JN4y1x7F6', 1),
#  ('BV1js41137ic', 1),
#  ('BV1jW411T7S3', 1),
#  ('BV1Jx411u734', 1),
#  ('BV1k7411f7gj', 1),
#  ('BV1kE411y7Pq', 1),
#  ('BV1kE421V7C4', 1),
#  ('BV1KG4y1n74v', 1),
#  ('BV1KH4y1u7sk', 1),
#  ('BV1KJ411U7GQ', 1),
#  ('BV1kQ4y1e7Qa', 1),
#  ('BV1ks411L7rk', 1),
#  ('BV1kt411v7rF', 1),
#  ('BV1kv41167s6', 1),
#  ('BV1Kv411b7u4', 1),
#  ('BV1kV411V7ct', 1),
#  ('BV1kW4y1j7Px', 1),
#  ('BV1Kx411n7kp', 1),
#  ('BV1Kx4reHEAe', 1),
#  ('BV1LA411x7i7', 1),
#  ('BV1Lh411Z7p4', 1),
#  ('BV1LM4m117Yz', 1),
#  ('BV1Lt421h7qQ', 1),
#  ('BV1LZ421K7xK', 1),
#  ('BV1M4411U76v', 1),
#  ('BV1M64y1u7TD', 1),
#  ('BV1Mb411N7M8', 1),
#  ('BV1ME411e7Um', 1),
#  ('BV1Mf4y1R79z', 1),
#  ('BV1mh4y1Z7vm', 1),
#  ('BV1mJ411371q', 1),
#  ('BV1MJ411r7HP', 1),
#  ('BV1MJ411X7sX', 1),
#  ('BV1mK4y1E7rP', 1),
#  ('BV1mM4m1D7nB', 1),
#  ('BV1MMtXe4E3R', 1),
#  ('BV1Mr421w7jp', 1),
#  ('BV1Mt4y1m7Qo', 1),
#  ('BV1Mt4y1M7xm', 1),
#  ('BV1mV4y1D7AE', 1),
#  ('BV1Mx411u7GG', 1),
#  ('BV1N14y1Y7vc', 1),
#  ('BV1N24y177zJ', 1),
#  ('BV1N44y1a7pP', 1),
#  ('BV1Na4y147os', 1),
#  ('BV1Nb4y1d74S', 1),
#  ('BV1Ne4y1k76Y', 1),
#  ('BV1NH4y1U7qg', 1),
#  ('BV1Nj41137MC', 1),
#  ('BV1nt411z76q', 1),
#  ('BV1NU4y1w7Tv', 1),
#  ('BV1Nx411U72c', 1),
#  ('BV1nx411Y7Hg', 1),
#  ('BV1o64y1677c', 1),
#  ('BV1ok4y1t7CK', 1),
#  ('BV1ou411B7mV', 1),
#  ('BV1oV4y1u7SL', 1),
#  ('BV1P24y117zc', 1),
#  ('BV1P442197wo', 1),
#  ('BV1PA41177tr', 1),
#  ('BV1pb411t7yn', 1),
#  ('BV1pD4y1978B', 1),
#  ('BV1PD4y1b75R', 1),
#  ('BV1PE411i7KL', 1),
#  ('BV1pE411N7Xo', 1),
#  ('BV1pF411E7EN', 1),
#  ('BV1PT4y1F7zq', 1),
#  ('BV1pW411879X', 1),
#  ('BV1pw411e7AG', 1),
#  ('BV1PW411E7DT', 1),
#  ('BV1px411H7vq', 1),
#  ('BV1px411U7TS', 1),
#  ('BV1py4y1r7NV', 1),
#  ('BV1PZ4y1g7TA', 1),
#  ('BV1pz4y1r7YD', 1),
#  ('BV1Q441157S9', 1),
#  ('BV1Q4411L7JQ', 1),
#  ('BV1Q84y1S7Jx', 1),
#  ('BV1qa4y1v7eK', 1),
#  ('BV1qC4y1h7VX', 1),
#  ('BV1qd4y1g7kr', 1),
#  ('BV1QE411u75Z', 1),
#  ('BV1qL4y1G7yL', 1),
#  ('BV1QP41147TK', 1),
#  ('BV1Qp4y1a7gx', 1),
#  ('BV1Qt411A7zi', 1),
#  ('BV1Qt411L7kX', 1),
#  ('BV1Qt411Z7w9', 1),
#  ('BV1qx411D7Yj', 1),
#  ('BV1qX4y1w7Vg', 1),
#  ('BV1QY4y1g7TT', 1),
#  ('BV1r541147u8', 1),
#  ('BV1RE411R7td', 1),
#  ('BV1Rf4y147y9', 1),
#  ('BV1rj411d7ag', 1),
#  ('BV1rJ411v7Zp', 1),
#  ('BV1Rt421M7iU', 1),
#  ('BV1RU411U7Bt', 1),
#  ('BV1RW411M7iC', 1),
#  ('BV1Rx4y1b74Z', 1),
#  ('BV1rZ4y1C71U', 1),
#  ('BV1rz4y1C7ZJ', 1),
#  ('BV1RZ4y1G7WK', 1),
#  ('BV1s3411z7kW', 1),
#  ('BV1s441137Qx', 1),
#  ('BV1S4411x7U6', 1),
#  ('BV1S54y1q7ew', 1),
#  ('BV1S64y1B7UL', 1),
#  ('BV1s7411G75m', 1),
#  ('BV1s84y1U7RL', 1),
#  ('BV1s94y147Xr', 1),
#  ('BV1s94y1G7ZD', 1),
#  ('BV1SB4y1N7m5', 1),
#  ('BV1sE41187V9', 1),
#  ('BV1sH4y1R7sc', 1),
#  ('BV1sK4y1E7NW', 1),
#  ('BV1sq4y1Q7ET', 1),
#  ('BV1Sr4y1Q7rM', 1),
#  ('BV1SV4y1e72K', 1),
#  ('BV1sW411j7C5', 1),
#  ('BV1SW411K76z', 1),
#  ('BV1sW411L7Tp', 1),
#  ('BV1T341167kk', 1),
#  ('BV1tb411f72L', 1),
#  ('BV1TG411k7z6', 1),
#  ('BV1TJ411J7ju', 1),
#  ('BV1TL411b7fV', 1),
#  ('BV1TS411c7PH', 1),
#  ('BV1Tt41177Bq', 1),
#  ('BV1Tx411R7ZP', 1),
#  ('BV1tX4y1T7Wb', 1),
#  ('BV1u54y1d7Pz', 1),
#  ('BV1UB4y1M77a', 1),
#  ('BV1UC4y1s7fY', 1),
#  ('BV1UD4y1v7sn', 1),
#  ('BV1uE411r78M', 1),
#  ('BV1UF4m1P7dg', 1),
#  ('BV1Ug41117oA', 1),
#  ('BV1uh411x7iU', 1),
#  ('BV1up411d7Jg', 1),
#  ('BV1Up411Z79D', 1),
#  ('BV1uW411R7bk', 1),
#  ('BV1v4411b7uB', 1),
#  ('BV1v7411v7Fs', 1),
#  ('BV1Vb411A7yh', 1),
#  ('BV1vb411j7sB', 1),
#  ('BV1Vh41127UV', 1),
#  ('BV1vh411Z7ss', 1),
#  ('BV1vJ411D7PX', 1),
#  ('BV1vK411g78N', 1),
#  ('BV1VQ4y1W7zn', 1),
#  ('BV1vqC9Y8E2o', 1),
#  ('BV1Vr4y1X7fu', 1),
#  ('BV1vt41117Ar', 1),
#  ('BV1vW411Y7nv', 1),
#  ('BV1vx41177j4', 1),
#  ('BV1vX4y1T7pN', 1),
#  ('BV1Vz4y1G7uk', 1),
#  ('BV1vZ4y1U7Y3', 1),
#  ('BV1vZ4y1X7rd', 1),
#  ('BV1Vz4y1y7s2', 1),
#  ('BV1W4411Z7dM', 1),
#  ('BV1WA411M74F', 1),
#  ('BV1wb411x7VW', 1),
#  ('BV1WD4y1R7cE', 1),
#  ('BV1wh411i7Nf', 1),
#  ('BV1wh4y1d7rh', 1),
#  ('BV1wJ411s7nA', 1),
#  ('BV1WN411m7do', 1),
#  ('BV1wt421t7Ta', 1),
#  ('BV1wW421d7dE', 1),
#  ('BV1Wx411H7wF', 1),
#  ('BV1wz421B7n9', 1),
#  ('BV1WZ4y1r7wP', 1),
#  ('BV1x24y1P7RF', 1),
#  ('BV1X3411P72x', 1),
#  ('BV1X4411b7xt', 1),
#  ('BV1X4411J7d4', 1),
#  ('BV1X4411U7Uo', 1),
#  ('BV1x44y1m7DN', 1),
#  ('BV1XA411T7Wd', 1),
#  ('BV1xb411373u', 1),
#  ('BV1Xb411G7rS', 1),
#  ('BV1xe41137Tj', 1),
#  ('BV1Xh411874Y', 1),
#  ('BV1Xh411Y7Fn', 1),
#  ('BV1Xi4y1G7X6', 1),
#  ('BV1xJ411i7ZX', 1),
#  ('BV1XK4y1r7w8', 1),
#  ('BV1Xq4y1s7c1', 1),
#  ('BV1xt4y1D7Ph', 1),
#  ('BV1xu411o7E3', 1),
#  ('BV1Xv411A7wt', 1),
#  ...]

# %%
G_without_kw_edges_vid_nodes = copy.deepcopy(G_without_kw_edges)
nodes_to_remove = [u for u, data in G_without_kw_edges.nodes(data=True) if data.get('type') == 'document']
# Remove the edges from the graph
G_without_kw_edges_vid_nodes.remove_nodes_from(nodes_to_remove)

# %%
recommend_based_on_keywords(G_without_kw_edges_vid_nodes, ['华为', '小米', '手机'])
# Out:
# [(67299944, 3),
#  (1959209, 3),
#  (475961, 3),
#  (8969156, 3),
#  (8372353, 3),
#  (8482768, 3),
#  (67991584, 3),
#  (3766866, 3),
#  (546418, 3),
#  (367877, 3),
#  (2233213, 3),
#  (10850097, 3),
#  (61086273, 3),
#  (50444181, 3),
#  (11336264, 3),
#  (8784855, 3),
#  (12590, 3),
#  (946974, 3),
#  (41820, 3),
#  (4401694, 3),
#  (13565996, 3),
#  (13407784, 3),
#  (9321359, 3),
#  (67368617, 3),
#  (12145493, 3),
#  (287795639, 3),
#  (957060, 3),
#  (5626102, 3),
#  (65764710, 3),
#  (12300996, 3),
#  (18937162, 3),
#  (3530725, 3),
#  (7458285, 3),
#  (11978336, 3),
#  (3743849, 3),
#  (10698051, 3),
#  (37029661, 1),
#  (12119849, 1),
#  (62986950, 1),
#  (453972, 1),
#  (2351309, 1),
#  (12434430, 1),
#  (11914415, 1),
#  (14583962, 1),
#  (4835329, 1),
#  (5128788, 1),
#  (79888370, 1),
#  (11021614, 1),
#  (6314588, 1),
#  (6905829, 1),
#  (74529609, 1),
#  (64219557, 1)]

# %%
print(G.size(), G_without_kw_edges.size(), G_without_kw_edges_vid_nodes.size())
# Out:
# 1218166 565302 97744

# %%
G_without_kw_edges.size()
# Out:
# 571727

# %%
keywords = [node for node, data in G.nodes(data=True) if data.get('type') == 'keyword']

# Step 2: Save keywords to a file
with open("keywords.txt", "w") as file:
    for keyword in keywords:
        file.write(f"{keyword}\n")

# %%
keywords.__len__()
# Out:
# 53048

# %%
### rec up by up

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Step 1: Build a TF-IDF matrix based on authors and keywords
def create_tfidf_matrix(graph):
    # Extract author-keyword edges
    author_keyword_edges = [(u, v) for u, v, data in graph.edges(data=True) if graph.nodes[u].get('type') == 'author' and graph.nodes[v].get('type') == 'keyword']
    
    # Create a dictionary of authors and their associated keywords
    author_keywords = {}
    for author, keyword in author_keyword_edges:
        if author not in author_keywords:
            author_keywords[author] = []
        author_keywords[author].append(keyword)
    
    # Convert the dictionary into a list of keyword lists for each author
    author_keyword_lists = [' '.join(keywords) for keywords in author_keywords.values()]
    
    # Step 2: Create the TF-IDF matrix using TfidfVectorizer
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(author_keyword_lists)
    
    return tfidf_matrix, list(author_keywords.keys()), vectorizer

# Step 3: Compute the similarity between the given author and all other authors
def compute_similarity(tfidf_matrix, author_list, given_author, vectorizer):
    # Find the index of the given author
    author_index = author_list.index(given_author)
    
    # Compute cosine similarities between the given author and all others
    cosine_sim = cosine_similarity(tfidf_matrix[author_index], tfidf_matrix).flatten()
    
    # Sort the similarities in descending order and get the most similar authors
    similar_authors_indices = cosine_sim.argsort()[-2:][::-1]  # Top 2, excluding the given author
    similar_authors = [author_list[i] for i in similar_authors_indices]
    similarity_scores = [cosine_sim[i] for i in similar_authors_indices]
    
    return similar_authors, similarity_scores

# Step 4: Find the shortest path between the given author and the recommended author
def find_shortest_path(graph, author1, author2):
    try:
        # Find the shortest path between the two authors
        path = nx.shortest_path(graph, source=author1, target=author2)
        path_length = len(path) - 1
    except nx.NetworkXNoPath:
        path = None
        path_length = None
    
    return path, path_length

# Example usage
# Assuming you already have the graph 'G' built with author-keyword edges

# Create the TF-IDF matrix
tfidf_matrix, author_list, vectorizer = create_tfidf_matrix(G)

# Given an author (replace with a real author name)
given_author = 4401694

# Compute similarity
similar_authors, similarity_scores = compute_similarity(tfidf_matrix, author_list, given_author, vectorizer)

# Get the most similar author
recommended_author = similar_authors[1:6]
similarity_score = similarity_scores[1:6]

# Find the shortest path between the given author and the recommended author
for i in range(len(recommended_author)):
    au = recommended_author[i]
    shortest_path, path_length = find_shortest_path(G, given_author, au)
    # Display the results
    print(f"Recommended Author: {recommended_author[i]}")
    print(f"Similarity Score: {similarity_score[i]}")
    print(f"Shortest Path: {shortest_path}")
    print(f"Path Length: {path_length}")
# Out:
# Recommended Author: 546418
# Similarity Score: 0.26127305013244956
# Shortest Path: [4401694, 'APPLE', 546418]
# Path Length: 2
